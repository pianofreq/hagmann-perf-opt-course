# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

plt.style.use('seaborn')

# %%
nyse = pd.read_csv('nasdaq_tickers.csv', index_col='Symbol').drop(columns=['Last Sale', 'Net Change', '% Change'])
nasdaq = pd.read_csv('nyse_tickers.csv', index_col='Symbol').drop(columns=['Last Sale', 'Net Change', '% Change'])
uni = nyse.append(nasdaq)
raw = pd.DataFrame()

# %%
int(len(uni.index)/103) raw.append()
# Out:
#   File "/tmp/ipykernel_24441/302103985.py", line 1
#     int(len(uni.index)/103) raw.append()
#                               ^
# SyntaxError: invalid syntax

# %%
for i in range(int(len(uni.index)/103)):
    raw = pd.DataFrame()
    chunk = pd.DataFrame()
    
    chunk = yf.download(list((uni.index))[i*int(len(uni.index)/103):(i+1)*int(len(uni.index)/103)],\
                        show_errors=True, timeout=2,prepost=True, period='max')
    
    raw = raw.append(chunk)
    raw.to_csv('rc_{:02d}_of_{:02d}.csv'.format(i,int(len(uni.index)/103)))
    

    
    print("chunk {} of {} complete".format(i,int(len(uni.index)/103)))
# Out:
# [*********************100%***********************]  80 of 80 completed
#
# 1 Failed download:
# - ACAXR: No data found for this date range, symbol may be delisted
# chunk 0 of 80 complete
# [*********************100%***********************]  80 of 80 completed
#
# 3 Failed downloads:
# - AGBAR: No data found for this date range, symbol may be delisted
# - ADOCR: No data found for this date range, symbol may be delisted
# - AEP: No data found for this date range, symbol may be delisted
# chunk 1 of 80 complete
# [*********************100%***********************]  80 of 80 completed
#
# 2 Failed downloads:
# - AIBBR: No data found for this date range, symbol may be delisted
# - ALSAR: No data found for this date range, symbol may be delisted
# chunk 2 of 80 complete
# [*********************100%***********************]  80 of 80 completed
#
# 2 Failed downloads:
# - ANDE: No data found for this date range, symbol may be delisted
# ...

# %%
raw1.info()

# %%
for i in range(int(len(uni.index)/515)):
    print(i)

# %%
raw.to_csv('raw_chunk_{}_of_{}.csv'.format(i,int(len(uni.index)/103)))

# %%
'raw_chunk_{:02d}_of_{:02d}.csv'.format(5,10)

# %%
raw.append(
